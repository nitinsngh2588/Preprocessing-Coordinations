# %% [markdown]
# # **Clustering Assignment**

# %% [markdown]
# ## Preprocessing

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# getting data from internet
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text

# using beautiful soup to parse the HTML/XML codes.
soup = BeautifulSoup(raw_wikipedia_page,'xml')
#print(soup.prettify())

# %% [markdown]
# ## **Processing-part-1: extracting raw table (from webpage)**

# %%
# extracting the raw table inside that webpage
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)

# extracting a clean form of the table
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
        if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'):
            
            continue
            
           
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            
            continue
            
            
    except:
        
        pass
    
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        
        continue
        
        
        
        
        
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %% [markdown]
# ## **Processing-part-2: integrating Postal codes with more than 1 neighbour**

# %%
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 77

# %% [markdown]
# ## **Post-processing: creating an appropriate Pandas Dataframe**

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
df_toronto.head(77)
# Out:
#    Postcode           Borough  \
# 0       M6S      West Toronto
# 1       M6M              York
# 2       M2K        North York
# 3       M4X  Downtown Toronto
# 4       M5P   Central Toronto
# 5       M6H      West Toronto
# 6       M5M        North York
# 7       M9C         Etobicoke
# 8       M2M        North York
# 9       M4B         East York
# 10      M2J        North York
# 11      M1K       Scarborough
# 12      M9M        North York
# 13      M4A        North York
# 14      M8V         Etobicoke
# 15      M1L       Scarborough
# 16      M6J      West Toronto
# 17      M4W  Downtown Toronto
# 18      M5A  Downtown Toronto
# 19      M9A         Etobicoke
# 20      M4N   Central Toronto
# 21      M1G       Scarborough
# 22      M3H        North York
# 23      M4G         East York
# 24      M2H        North York
# 25      M9V         Etobicoke
# 26      M5E  Downtown Toronto
# 27      M5X  Downtown Toronto
# 28      M1M       Scarborough
# 29      M1N       Scarborough
# ..      ...               ...
# 47      M5J  Downtown Toronto
# 48      M4C         East York
# 49      M1P       Scarborough
# 50      M1B       Scarborough
# 51      M6P      West Toronto
# 52      M1E       Scarborough
# 53      M1V       Scarborough
# 54      M6K      West Toronto
# 55      M3C        North York
# 56      M8X         Etobicoke
# 57      M8W         Etobicoke
# 58      M4H         East York
# 59      M4Y  Downtown Toronto
# 60      M4V   Central Toronto
# 61      M3J        North York
# 62      M5T  Downtown Toronto
# 63      M4T   Central Toronto
# 64      M1S       Scarborough
# 65      M6A        North York
# 66      M4J         East York
# 67      M4K      East Toronto
# 68      M5L  Downtown Toronto
# 69      M9R         Etobicoke
# 70      M1J       Scarborough
# 71      M6R      West Toronto
# 72      M3L        North York
# 73      M3K        North York
# 74      M5R   Central Toronto
# 75      M9B         Etobicoke
# 76      M5K  Downtown Toronto
#
#                                         Neighbourhood
# 0                                  Runnymede, Swansea
# 1               Keelesdale, Mount Dennis, Silverthorn
# 2                                     Bayview Village
# 3                         Cabbagetown, St. James Town
# 4                                   Forest Hill North
# 5                                  Dovercourt Village
# 6                                        Bedford Park
# 7                                       Markland Wood
# 8                             Newtonbrook, Willowdale
# 9                     Woodbine Gardens, Parkview Hill
# 10                                         Henry Farm
# 11                              Ionview, Kennedy Park
# 12                                   Emery, Humberlea
# 13                                   Victoria Village
# 14                                        New Toronto
# 15                    Clairlea, Golden Mile, Oakridge
# 16                           Little Portugal, Trinity
# 17                                           Rosedale
# 18                          Harbourfront, Regent Park
# 19                                   Islington Avenue
# 20                                      Lawrence Park
# 21                                             Woburn
# 22                     Bathurst Manor, Wilson Heights
# 23                                            Leaside
# 24                                  Hillcrest Village
# 25  Beaumond Heights, Jamestown, Mount Olive, Silv...
# 26                                        Berczy Park
# 27             First Canadian Place, Underground city
# 28                              Cliffcrest, Cliffside
# 29                                        Birch Cliff
# ..                                                ...
# 47                     Toronto Islands, Union Station
# 48                                   Woodbine Heights
# 49  Dorset Park, Scarborough Town Centre, Wexford ...
# 50                                     Rouge, Malvern
# 51                                          High Park
# 52                             Morningside, West Hill
# 53                          Agincourt North, Milliken
# 54                 Exhibition Place, Parkdale Village
# 55                                    Flemingdon Park
# 56                                       The Kingsway
# 57                             Alderwood, Long Branch
# 58                                   Thorncliffe Park
# 59                               Church and Wellesley
# 60                   Deer Park, Rathnelly, South Hill
# 61                    Northwood Park, York University
# 62          Chinatown, Grange Park, Kensington Market
# 63                                         Moore Park
# 64                                          Agincourt
# 65                   Lawrence Heights, Lawrence Manor
# 66                                       East Toronto
# 67                                          Riverdale
# 68                                     Commerce Court
# 69                                  Kingsview Village
# 70                                Scarborough Village
# 71                             Parkdale, Roncesvalles
# 72                                     Downsview West
# 73                                        CFB Toronto
# 74                               The Annex, Yorkville
# 75       Islington, Princess Gardens, West Deane Park
# 76           Design Exchange, Toronto Dominion Centre
#
# [77 rows x 3 columns]

# %%
df_toronto=df_toronto.rename(columns={'Postcode':'Postal Code'})
df_toronto.head()
# Out:
#   Postal Code           Borough                          Neighbourhood
# 0         M6S      West Toronto                     Runnymede, Swansea
# 1         M6M              York  Keelesdale, Mount Dennis, Silverthorn
# 2         M2K        North York                        Bayview Village
# 3         M4X  Downtown Toronto            Cabbagetown, St. James Town
# 4         M5P   Central Toronto                      Forest Hill North

# %%
print('geocoder has been installed before.')
import geocoder
print('geocoder has been successfully imported.')
# Out:
# geocoder has been installed before.
# geocoder has been successfully imported.

# %%
df= pd.read_csv('Desktop/Geospatial_Coordinates.csv')

# %%
latitude = []
longitude = []
for elem in Postcode_u:
# initialize your variable to None
    lat_lng_coords = None

# loop until you get the coordinates
    while (lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(elem))
        lat_lng_coords = g.latlng
        # print(lat_lng_coords)

    latitude.append(lat_lng_coords[0])
    longitude.append(lat_lng_coords[1])
    print(elem, 'is RECEIVED.')
    # print(lat_lng_coords[0])
    # print(lat_lng_coords[1])

# %%
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
data_df = pd.merge(df,df_toronto,how='inner', on=['Postal Code'])

# %%
data_df.head()
# Out:
#   Postal Code   Latitude  Longitude      Borough  \
# 0         M1B  43.806686 -79.194353  Scarborough
# 1         M1C  43.784535 -79.160497  Scarborough
# 2         M1E  43.763573 -79.188711  Scarborough
# 3         M1G  43.770992 -79.216917  Scarborough
# 4         M1J  43.744734 -79.239476  Scarborough
#
#                             Neighbourhood
# 0                          Rouge, Malvern
# 1  Highland Creek, Rouge Hill, Port Union
# 2                  Morningside, West Hill
# 3                                  Woburn
# 4                     Scarborough Village

# %%
data_df = data_df[['Postal Code','Borough','Neighbourhood','Latitude','Longitude']]
data_df.head(20)
# Out:
#    Postal Code      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1J  Scarborough
# 5          M1K  Scarborough
# 6          M1L  Scarborough
# 7          M1M  Scarborough
# 8          M1N  Scarborough
# 9          M1P  Scarborough
# 10         M1R  Scarborough
# 11         M1S  Scarborough
# 12         M1T  Scarborough
# 13         M1V  Scarborough
# 14         M1X  Scarborough
# 15         M2H   North York
# 16         M2J   North York
# 17         M2K   North York
# 18         M2L   North York
# 19         M2M   North York
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                      Rouge, Malvern  43.806686 -79.194353
# 1              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2                              Morningside, West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                 Scarborough Village  43.744734 -79.239476
# 5                               Ionview, Kennedy Park  43.727929 -79.262029
# 6                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 7                               Cliffcrest, Cliffside  43.716316 -79.239476
# 8                                         Birch Cliff  43.692657 -79.264848
# 9   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 10                                  Maryvale, Wexford  43.750072 -79.295849
# 11                                          Agincourt  43.794200 -79.262029
# 12                                      Tam O'Shanter  43.781638 -79.304302
# 13                          Agincourt North, Milliken  43.815252 -79.284577
# 14                                        Upper Rouge  43.836125 -79.205636
# 15                                  Hillcrest Village  43.803762 -79.363452
# 16                                         Henry Farm  43.778517 -79.346556
# 17                                    Bayview Village  43.786947 -79.385975
# 18                                         York Mills  43.757490 -79.374714
# 19                            Newtonbrook, Willowdale  43.789053 -79.408493
